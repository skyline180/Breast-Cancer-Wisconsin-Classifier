# %% [markdown]
# # Breast Cancer Wisconsin Exploration
# This notebook loads the dataset, checks the columns, and trains a baseline classifier.

# %%
from src.data.load_data import load_and_prepare_data
from src.utils.helpers import summarize_dataframe
from pathlib import Path

data_path = Path('../data/raw/breast-cancer-wisconsin.csv')
df = load_and_prepare_data(data_path)
summarize_dataframe(df)

# %%
df.head()

# %%
df['diagnosis'].value_counts()

# %% [markdown]
# ## Train a baseline model
# Use the command line training script in `src/models/train.py`.
